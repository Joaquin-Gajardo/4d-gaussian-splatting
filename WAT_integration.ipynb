# %%
from pathlib import Path
from PIL import Image

import numpy as np

# %%
def checks(scene_path):
    scene = scene_path.name
    # Check that all videos are there
    dataset_path_videos = [path for path in scene_path.iterdir() if path.name.endswith('.mp4')] 
    assert len(dataset_path_videos) == 21 if not scene == 'cut_roasted_beef' else len(dataset_path_videos) == 20, \
    f'There should be 20 videos for each scene in this dataset. Problem: scene {scene}'

    # Check that all images are there and have the same amount of images
    dataset_path_images = [path.parent / path.stem / 'images' for path in dataset_path_videos]
    assert all([path.exists() for path in dataset_path_images]), 'Not all images folders exist'
    assert len(set([len(list(path.iterdir())) for path in dataset_path_images])) == 1, 'Not all images folders have the same amount of images'

    # Check that there is no corrupted image (OSError)
    for camera_images_path in dataset_path_images:
        for image_path in camera_images_path.iterdir():
            try:
                image = Image.open(image_path)
                image.verify()
            except OSError:
                print(f'Scene {scene} is corrupted. Corrupted image at {image_path}')
                break

# %%
dataset_path = Path(f'../../../datasets/dynerf')
for scene_path in dataset_path.iterdir():
    scene = scene_path.name
    print('Checking scene:', scene)
    checks(dataset_path / scene)
    print('OK')
print('All checks passed for all scenes')
# Out:
# Checking scene: flame_steak
# OK
# Checking scene: cut_roasted_beef
# OK
# Checking scene: cook_spinach
# OK
# All checks passed for all scenes

# %%
path = Path(f'data/WAT/breville/images/IMG_9185/IMG_9185_370.png')
image = Image.open(path)
image.convert('RGBA')
# Out:
# <PIL.Image.Image image mode=RGBA size=1920x1440>

# %%
np.array(image.load()).shape
# Out:
# ()

# %%
im_data = np.array(image.convert("RGBA"))

# %%
im_data.shape
# Out:
# (1440, 1920, 4)

# %%
import os
from PIL import Image, ImageFile
import numpy as np
import logging

# Allow loading truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = False

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def load_image_robustly(file_path):
    try:
        with Image.open(file_path) as img:
            # Force loading of image data
            img.load()
            
            # Convert to RGB if it's not already
            if img.mode != 'RGB':
                img = img.convert('RGB')
            

            # Convert to numpy array
            np_array = np.array(img)
            
            height, width = img.size
            logging.info(f"Successfully loaded image: {file_path}. Height={height}, width={width}.")
            return np_array
    except (OSError, IOError) as e:
        logging.error(f"Error loading image {file_path}: {str(e)}")
        return None

def process_image_directory(directory):
    successful_loads = 0
    failed_loads = 0
    
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                file_path = os.path.join(root, file)
                result = load_image_robustly(file_path)
                if result is not None:
                    successful_loads += 1
                else:
                    failed_loads += 1
    
    logging.info(f"Processed {successful_loads + failed_loads} images.")
    logging.info(f"Successfully loaded: {successful_loads}")
    logging.info(f"Failed to load: {failed_loads}")

# Usage
image_directory = "data/WAT/breville/images"
process_image_directory(image_directory)
# Out:
# 2024-09-13 15:57:42,150 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_590.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,222 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_480.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,283 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_420.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,337 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_290.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,392 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_140.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,444 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_270.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,498 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_430.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,552 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_120.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,604 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_500.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,658 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_510.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,713 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_560.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,766 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_260.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,821 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_50.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,874 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_240.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,928 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_180.png. Height=1920, width=1440.
# 2024-09-13 15:57:42,982 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_530.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,035 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_340.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,085 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_250.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,139 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_110.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,194 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_160.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,249 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_400.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,304 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_220.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,363 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_330.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,419 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_520.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,474 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_570.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,528 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185_370.png. Height=1920, width=1440.
# 2024-09-13 15:57:43,583 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9185/IMG_9185
- INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_390.png. Height=1920, width=1440.
# 2024-09-13 15:57:52,957 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_330.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,013 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_270.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,070 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_80.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,127 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_30.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,183 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_0.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,240 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_540.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,297 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_10.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,354 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_480.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,410 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_120.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,466 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_170.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,534 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_460.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,596 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_280.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,654 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_340.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,712 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_370.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,769 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_180.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,826 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_440.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,883 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_210.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,940 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_230.png. Height=1920, width=1440.
# 2024-09-13 15:57:53,997 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_350.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,054 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_150.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,111 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_450.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,179 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_130.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,239 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9184/IMG_9184_90.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,295 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_380.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,352 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_490.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,410 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_20.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,468 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_80.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,527 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_510.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,585 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_310.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,641 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_500.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,697 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_160.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,770 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_100.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,827 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_550.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,885 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_130.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,939 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_240.png. Height=1920, width=1440.
# 2024-09-13 15:57:54,997 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_470.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,053 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_180.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,111 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_150.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,167 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_350.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,224 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_210.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,281 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_430.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,335 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_0.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,393 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_60.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,457 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_420.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,517 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_270.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,572 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_40.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,631 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_330.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,687 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_280.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,743 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_120.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,799 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_440.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,855 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_530.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,911 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_400.png. Height=1920, width=1440.
# 2024-09-13 15:57:55,967 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_200.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,023 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_340.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,079 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_10.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,135 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_260.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,191 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_390.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,247 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_110.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,304 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_300.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,360 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_410.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,416 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_370.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,472 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_320.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,525 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_250.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,580 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_90.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,636 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_190.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,692 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_30.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,749 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_450.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,804 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_520.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,859 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_50.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,912 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_230.png. Height=1920, width=1440.
# 2024-09-13 15:57:56,968 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_480.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,024 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_540.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,079 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_360.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,136 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_460.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,204 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_70.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,263 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_220.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,320 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_140.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,375 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_290.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,431 - INFO - Successfully loaded image: data/WAT/breville/images/IMG_9188/IMG_9188_170.png. Height=1920, width=1440.
# 2024-09-13 15:57:57,432 - INFO - Processed 267 images.
# 2024-09-13 15:57:57,433 - INFO - Successfully loaded: 267
# 2024-09-13 15:57:57,434 - INFO - Failed to load: 0

# %%
import os
from PIL import Image
import torch
from torchvision import transforms
from concurrent.futures import ThreadPoolExecutor, as_completed

def validate_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True, file_path
    except Exception as e:
        return False, (file_path, str(e))

def validate_dataset(dataset_path):
    image_files = [os.path.join(root, file) 
                   for root, _, files in os.walk(dataset_path) 
                   for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    valid_images = []
    invalid_images = []

    with ThreadPoolExecutor() as executor:
        futures = [executor.submit(validate_image, file_path) for file_path in image_files]
        for future in as_completed(futures):
            is_valid, result = future.result()
            if is_valid:
                valid_images.append(result)
            else:
                invalid_images.append(result)

    print(f"Total images: {len(image_files)}")
    print(f"Valid images: {len(valid_images)}")
    print(f"Invalid images: {len(invalid_images)}")
    
    if invalid_images:
        print("Invalid images:")
        for file_path, error in invalid_images:
            print(f"  {file_path}: {error}")

    return valid_images, invalid_images

# Usage
dataset_path = "data/WAT/breville/images"
valid_images, invalid_images = validate_dataset(dataset_path)
# Out:
# Total images: 267
# Valid images: 267
# Invalid images: 0

# %%
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_260.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9186/IMG_9186_410.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9187/IMG_9187_430.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_390.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9186/IMG_9186_0.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_500.png'

'Combinations:'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_260.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9186/IMG_9186_410.png'

'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_390.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9187/IMG_9187_430.png'

'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_310.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_390.png'

'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_260.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9187/IMG_9187_430.png'

'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_260.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9187/IMG_9187_430.png'

'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9187/IMG_9187_430.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_390.png'

'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9187/IMG_9187_430.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_500.png'

'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_260.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9187/IMG_9187_430.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_390.png'

'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9187/IMG_9187_430.png'
'/workspace/4d-gaussian-splatting/data/WAT/breville/images/IMG_9185/IMG_9185_390.png'
